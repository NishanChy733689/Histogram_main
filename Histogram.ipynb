# %% [markdown]
# <a href="https://colab.research.google.com/github/NishanChy733689/Global_population_analysis/blob/main/Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Histogram

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm")
plt.show()

# %%
sns.histplot(data=penguins,
            x="bill_length_mm")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            binwidth=1)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            binwidth=3)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            binwidth=5)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            bins=30)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            kde=True)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            multiple="stack")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            element="step")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            element="poly")
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            element="step",
            stat="density",
            common_norm=False)
plt.show()

# %%
sns.histplot(data=penguins,
            x="flipper_length_mm",
            hue="species",
            element="step",
            stat="density",
            common_norm=True)
plt.show()

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=tips, x ="size",
            stat="percent",
            discrete=True)
plt.show()

# %%
sns.histplot(data=tips,
             x ="day",
            shrink=0.8)
plt.show()

# %%
sns.histplot(data=tips,
             x ="day", hue="sex",
            shrink=0.8, multiple="dodge")
plt.show()

# %%
planets = sns.load_dataset("planets")

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.histplot(data=planets,
            x="distance")
plt.show()

# %%
sns.histplot(data=planets,
            x="distance",
            log_scale=True)
plt.show()

# %%
sns.histplot(data=planets,
            x="distance",
            log_scale=True,
            fill=False)
plt.show()

# %%
sns.histplot(data=planets,
            x="distance",
            log_scale=True,
            element="step",
            fill=False)
plt.show()

# %%
sns.histplot(penguins,
             y="body_mass_g",
            x="bill_depth_mm")
plt.show()

# %%
sns.histplot(penguins,
             y="body_mass_g",
            x="bill_depth_mm",
            hue="species")
plt.show()

# %%
sns.histplot(data=planets,
             y="distance",
            x="year", bins=30,
            discrete=(True, False),
            log_scale=(False, True))
plt.show()

# %%
sns.histplot(data=planets,
             y="distance",
            x="year", bins=30,
            discrete=(True, False),
            log_scale=(False, True),
             thresh=None)
plt.show()

# %%
sns.histplot(data=planets,
             y="distance",
            x="year", bins=30,
            discrete=(True, False),
            log_scale=(False, True),
             pthresh=0.5, pmax=0.9)
plt.show()

# %%
sns.histplot(data=planets,
             y="distance",
            x="year", bins=30,
            discrete=(True, False),
            log_scale=(False, True),
             cbar=True,
             cbar_kws=dict(shrink=0.75))
plt.show()
